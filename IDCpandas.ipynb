# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_rows = 8

# %% [markdown]
#  Importation des données

# %%
df = pd.read_csv("C:/Users/Fabrice/Documents/Travail en cours/Cours/M2 IDC Economie des apps et des objets connectés M2 IDC/data2021.csv")

# %%
df.head()
# Out:
#                                                 id  \
# 0                           automateit.mainpackage
# 1  bnpparibas.derivative.mobile.app.android.dailys
# 2                              com.sktelecom.minit
# 3                    drwebsterapps.bibletriviagame
# 4                                zxstyles.zxreader
#
#                                                id3  versioncode  \
# 0                           AutomateIt.mainPackage          241
# 1  BnpParibas.Derivative.Mobile.App.Android.Dailys           47
# 2                              Com.sktelecom.minit          148
# 3                    DrWebsterApps.BibleTriviaGame          310
# 4                                ZXStyles.ZXReader          268
#
#                                                 name   marketcategory   price  \
# 0  'AutomateIt - Automate tasks, save battery and...     PRODUCTIVITY  'free'
# 1                                     "Trader's Box"          FINANCE  'free'
# ...
